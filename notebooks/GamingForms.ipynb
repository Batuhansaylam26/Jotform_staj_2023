# %%
import pandas as pd 
from sqlite3 import connect
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from warnings import simplefilter
from scipy.signal import detrend
import matplotlib as mpl
import matplotlib.pyplot as plt
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.graphics.tsaplots import plot_pacf
sns.set()
import pandasql as psql
#machine learning and statistical methods
import statsmodels.api as sm
import math
#dataframe index manipulations
import datetime
from datetime import datetime
#selected preprocessing and evaluation methods
from sklearn.preprocessing import StandardScaler
from statsmodels.tsa.stattools import kpss
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from plotly.subplots import make_subplots
from statsmodels.tsa.seasonal import DecomposeResult
import plotly.graph_objects as go
from statsmodels.tsa.holtwinters import SimpleExpSmoothing, ExponentialSmoothing
from statsmodels.tsa.seasonal import seasonal_decompose
from sklearn.metrics import mean_absolute_percentage_error
from prophet import Prophet
from neuralprophet import NeuralProphet
import tensorflow as tf
import torch 




use_cuda = torch.cuda.is_available()
if use_cuda:
    print('__CUDNN VERSION:', torch.backends.cudnn.version())
    print('__Number CUDA Devices:', torch.cuda.device_count())
    print('__CUDA Device Name:',torch.cuda.get_device_name(0))
    print('__CUDA Device Total Memory [GB]:',torch.cuda.get_device_properties(0).total_memory/1e9)
use_cuda


tf.config.list_physical_devices('GPU')


formtemplatesclones=pd.read_csv("/home/batuhan-saylam/Desktop/JotformProject/formTemplatesClones.csv",parse_dates=["date"])
formtemplatescategories=pd.read_csv("/home/batuhan-saylam/Desktop/JotformProject/formTemplatesCategories.csv")
formtemplates=pd.read_excel("/home/batuhan-saylam/Desktop/JotformProject/formTemplates_1_.xlsx")







formtemplatescategoriesPharmacy=formtemplatescategories[formtemplatescategories["metaKeywords"]=='Gaming Forms']

formtemplatesclones=formtemplatesclones.rename({"templateID":"_id"},axis=1)
formtemplates=formtemplates.drop_duplicates()
formandclone=pd.merge(formtemplates,formtemplatesclones,on="_id")
formtemplates=formtemplates.rename({"_id":"id"},axis=1)
formtemplates=formtemplates.rename({"_featuredCategory":"_id"},axis=1)
formtemplates2=pd.merge(formtemplatescategoriesPharmacy,formtemplates,on="_id")
formtemplates2=formtemplates2.rename({"_id":"_featuredCategory"},axis=1)
formtemplates=formtemplates.rename({"_id":"_featuredCategory"},axis=1)
df_melt = formtemplates.assign(_categories=formtemplates._categories.str.split(","))
formtemplates=df_melt._categories.apply(pd.Series) \
    .merge(formtemplates, right_index=True, left_index=True) \
    .drop(["_categories"], axis=1) \
    .melt(id_vars=['id',"_title","_slug","_description","_featuredCategory","_language"], value_name="_categories") \
    .drop("variable", axis=1) 
formtemplates=formtemplates.rename({"_categories":"_id"},axis=1)
formtemplates3=pd.merge(formtemplatescategoriesPharmacy,formtemplates,on="_id")
formtemplates3=formtemplates3.rename({"_id":"_categories"},axis=1)
formtemplates=formtemplates.rename({"_id":"_categories"},axis=1)
formtemplates=formtemplates.rename({"id":"_id"},axis=1)
formcat=pd.concat([formtemplates2,formtemplates3])
formcat=formcat.rename({"id":"_id"},axis=1)
formcat=formcat.loc[:,[
 'name',
 'description',
 'metaKeywords',
 '_categories',
 '_id']]
formandclone=formandclone.loc[:,[
'_id',
 '_title',
 '_slug',
 '_description',
 '_language',
 '_featuredCategory',
 'formID',
 'form_type',
 'source',
 'date']]
formclonecategnonnanPharmacy=pd.merge(formandclone,formcat,on="_id")
formclonecategnonnanPharmacy=formclonecategnonnanPharmacy.drop_duplicates(keep='first')

formclonecategnonnanPharmacy.index=formclonecategnonnanPharmacy.date
formclonecategnonnanPharmacy.index=formclonecategnonnanPharmacy.index.to_period("D")
formclonecategnonnanPharmacy=formclonecategnonnanPharmacy.rename({"date":"date2"},axis=1)
formclonecategnonnanPharmacy["day"]=formclonecategnonnanPharmacy.index.dayofweek
formclonecategnonnanPharmacy["week"]=formclonecategnonnanPharmacy.index.week
formclonecategnonnanPharmacy["dayofyear"]=formclonecategnonnanPharmacy.index.dayofyear
formclonecategnonnanPharmacy["year"]=formclonecategnonnanPharmacy.index.year
formclonecategnonnanPharmacy["quarter"]=formclonecategnonnanPharmacy.index.quarter
formclonecategnonnanPharmacy["month"]=formclonecategnonnanPharmacy.index.month
formclonecategnonnanPharmacy.index=formclonecategnonnanPharmacy.index.to_timestamp()




df=psql.sqldf("select count(_id),date,year,dayofyear from formclonecategnonnanPharmacy  group by date")

df.index=df.date.tolist()
df.index=pd.to_datetime(df.index)
df.index=df.index.to_period("D")
df.index=df.index.to_timestamp()
df.index=df.index.strftime('%d-%m-%Y')
df["date"]=pd.to_datetime(df["date"])


df=df.rename({"count(_id)":"y"},axis=1)
df=df.rename({"date":"ds"},axis=1)
df=df.loc[:,["y","ds"]]
# Out:
# 2023-08-22 14:07:23.229926: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# __CUDNN VERSION: 8700
# __Number CUDA Devices: 1
# __CUDA Device Name: NVIDIA GeForce RTX 3050 Laptop GPU
# __CUDA Device Total Memory [GB]: 4.094164992
# 2023-08-22 14:07:24.182130: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2023-08-22 14:07:24.182619: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2023-08-22 14:07:24.183502: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-08-22 14:07:24.183773: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: NVIDIA GeForce RTX 3050 Laptop GPU computeCapability: 8.6
# coreClock: 1.035GHz coreCount: 16 deviceMemorySize: 3.81GiB deviceMemoryBandwidth: 163.94GiB/s
# 2023-08-22 14:07:24.183948: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2023-08-22 14:07:24.206216: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2023-08-22 14:07:24.206442: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.10
# 2023-08-22 14:07:24.206478: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2023-08-22 14:07:24.206501: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2023-08-22 14:07:24.227582: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2023-08-22 14:07:24.230692: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.10
# 2023-08-22 14:07:24.265308: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2023-08-22 14:07:24.265686: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-08-22 14:07:24.265921: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-08-22 14:07:24.266023: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0

# %%
decomposeresult2=seasonal_decompose(df["y"],period=365,model="add", extrapolate_trend = 'freq',two_sided=True)
season = pd.DataFrame({"obs":decomposeresult2.observed,"trend":decomposeresult2.trend,"seasonal":decomposeresult2.seasonal,"resid":decomposeresult2.resid})
season.index=pd.to_datetime(season.index,format="%d-%m-%Y")
season=season.fillna(0)
season=season.sort_index()
season.index=season.index.to_period("D")
season.index=season.index.to_timestamp()
season.index=season.index.strftime('%Y-%m-%d')

# %%
formtemplatescategories=pd.read_csv("/home/batuhan-saylam/Desktop/JotformProject/formTemplatesCategories.csv")
formtemplatescategories.metaKeywords.unique().tolist()
# Out:
# ['Pharmacy Forms',
#  'Gaming Forms',
#  'Tax Forms',
#  'Relationship Surveys',
#  'Summer Camp Evaluations',
#  'Summer Camp Medical Forms',
#  'Summer Camp Consent Forms',
#  'Summer Camp Job Application Forms',
#  'Coronavirus Related Forms',
#  'Telecommuting Forms',
#  'Telehealth Forms',
#  'Informed Consent Forms',
#  'Virtual Event Forms',
#  'salon, beauty,barber,hair dresser,hair',
#  'Botulinum Toxin Forms',
#  'CAHPS Surveys,HCAHPS',
#  'Dermal Filler Consent and Treatment Forms',
#  'Makeup Consultation and Consent Forms',
#  'Peer Feedback Forms',
#  'Parent Feedback Forms',
#  'Travel Feedback Forms',
#  'Service Feedback Forms',
#  'Patient Feedback Forms',
#  'Event Feedback Forms',
#  'Teacher Feedback Forms',
#  'Real Estate Feedback Forms',
#  'Open House Feedback Forms',
#  'Personal Training Feedback Forms',
#  'Teacher Evaluation Forms',
#  'Client Evaluation Forms',
#  'School Evaluation Forms',
#  'Event Evaluation Forms',
#  'Restaurant Evaluation Forms',
#  'Peer Evaluation Forms',
#  'Customer Satisfaction Evaluation Forms',
#  'Course Evaluation Forms',
#  'Service Evaluation Forms',
#  'Patient Enrollment Forms',
#  'Student Enrollment Forms',
#  'Employee Enrollment Forms',
#  'Camp Enrollment Forms',
#  'Benefits Enrollment Forms',
#  'School Enrollment Forms',
#  'Course Enrollment Forms',
#  'school survey',
#  'Employee Surveys',
#  'Satisfaction Surveys',
#  'Marketing Surveys',
#  'Vehicle Inspection Forms',
#  'Safety Inspection Forms',
#  'Home Inspection Forms',
#  'Fire Inspection Forms',
#  'Rental Property Inspection Forms',
#  'Product Surveys',
#  'Interview Forms',
#  'Guest Registration Forms',
#  'Medical Consent Forms',
#  'Travel Consent Forms',
#  'social worker',
#  'physician forms',
#  'Staff Forms',
#  'Teacher Forms',
#  'Investor Forms',
#  'Hotel Manager Forms',
#  'Model Forms',
#  'Firefighter Forms',
#  'Surveyor Forms',
#  'Web Designer Forms',
#  'Entrepreneur Forms',
#  'Salesman Forms',
#  'Manager Forms',
#  'Farmer Forms',
#  'Building Inspector Forms',
#  'Photographer Forms',
#  'Dietitian Forms',
#  'Software Developer Forms',
#  'Priest Forms',
#  'Chef Forms',
#  'Secretary Forms',
#  'Florist Forms',
#  'Electrician Forms',
#  'Missionary Forms',
#  'Plumber Forms',
#  'Fundraiser Forms',
#  'Hairdresser Forms',
#  'Appraiser Forms',
#  'Home Inspector Forms',
#  'Merchant Forms',
#  'Gamer Forms',
#  'Nonprofit Employee Forms',
#  'Personal Trainer Forms',
#  'Dentist Forms',
#  'Financial Advisor Forms',
#  'Psychologist Forms',
#  'Technician Forms',
#  'Esthetician Forms',
#  'Handyman Forms',
#  'Videographer Forms',
#  'Customer Service Agent Forms',
#  'Travel Agent Forms',
#  'Event Planner Forms',
#  'Contractor Forms',
#  'Police Officer Forms',
#  'Broker Forms',
#  'Lawyer Forms',
#  'Influencer Forms',
#  'Nurse Forms',
#  'Therapist Forms',
#  'Counselor Forms',
#  'Marketer Forms',
#  'Recruiter Forms',
#  'School Counselor Forms',
#  'Makeup Artist Forms',
#  'Health Coach Forms',
#  'Restaurant Manager Forms',
#  'Pharmacist Forms',
#  'Driver Forms',
#  'Librarian Forms',
#  'Veterinarian Forms',
#  'Athlete Forms',
#  'Legal Forms',
#  'Nail Artist Forms',
#  'Accountant Forms',
#  'Engineer Forms',
#  'Storekeeper Forms',
#  'Tutor Forms',
#  'Actor Forms',
#  'Real Estate Agent Forms ',
#  'Tattoo Artist Forms',
#  'Insurance Agent Forms',
#  'Hospice Forms',
#  'Business Report Forms',
#  'Incident Report Forms',
#  'Emergency Report Forms',
#  'Covid Report Forms',
#  'Shift Report Forms',
#  'K-12 Forms',
#  'Expense Tracking Forms',
#  'Health Tracking Forms',
#  'Performance Tracking Forms',
#  'Time Tracking Forms',
#  'Asset Tracking Forms',
#  'Habit Tracking Forms',
#  'Checklist Forms',
#  'Employment Release Forms',
#  'Hospital Release Forms',
#  'Daycare Forms',
#  'Disciplinary Forms',
#  'Technology Surveys',
#  'Dental Consent Forms',
#  'Property Management Forms',
#  'Cleaning Forms',
#  'Healthcare Surveys',
#  'Contact Forms',
#  'Event Registration Forms',
#  'Lead Generation Forms',
#  'Survey Form Templates',
#  'RSVP Forms',
#  'Payment Forms',
#  'charity',
#  'Education Forms',
#  'Business Forms',
#  'Donation Forms',
#  'Subscription Forms',
#  'marketing',
#  'Request Forms',
#  'advertising',
#  'e-commerce',
#  'Order Forms',
#  'Award Forms',
#  'Feedback',
#  'Application Forms',
#  'Wedding Forms',
#  'alumni',
#  'Services Forms',
#  'Recommendation Forms',
#  'sports',
#  'Tracking Forms',
#  'banking',
#  'Real Estate Form',
#  'Human Resources Forms',
#  'Registration Forms, newsletter',
#  'church',
#  'entertainment',
#  'File Upload Forms',
#  'consent form, consent form template, consent forms, consent form sample',
#  'Evaluation Forms',
#  'Sponsorship Forms',
#  'Booking Forms',
#  'Quote Forms',
#  'Reservation Forms',
#  'Content Forms',
#  'it forms',
#  'Customer Service Forms',
#  'Employment Forms',
#  'Sign Up Form Templates & Examples',
#  'SEO Form',
#  'Appointment Form',
#  'Membership Forms, newsletter',
#  'Summer Camps',
#  'audit form',
#  'Report Forms',
#  'Insurance Form',
#  'Healthcare Forms',
#  'Volunteer Forms, community service template',
#  'Petition Forms',
#  'Web Design',
#  'Enrollment',
#  'Polls',
#  'abstract form',
#  'pet services',
#  'Calculation Forms',
#  'Photography Forms',
#  'questionnaire form, questionnaire form template, example questionnaire form',
#  'voting,election',
#  'Medical Surveys & Questionnaires',
#  'Event Booking',
#  'inspection forms',
#  'Time Off Request Forms',
#  't-shirt order forms',
#  'apparel order forms, clothing order forms',
#  'Employee Evaluation Forms',
#  'Job Application Forms',
#  'cake order forms',
#  'photography order forms',
#  'product order forms',
#  'bakery order forms',
#  'cookie order forms',
#  'Employee Information Forms',
#  'Human Resources Surveys',
#  'Food & Beverage Order Forms',
#  'book order forms',
#  'Leave of Absence Forms',
#  'Employee Incident Report Forms',
#  'ticket order forms',
#  'purchase order forms, purchase order form',
#  'sales order forms',
#  'purchase order request forms, purchase order request form, purchase order request form template',
#  'Scholarship Application Forms, scholarship application form, sample scholarship application form,scholarship application template',
#  'Summer, Camp, Application, Forms, summer camp application forms, summer camp application form, sample summer camp application form',
#  'School Application Forms, school application form',
#  'sponsorship application form',
#  'contest entry form, contest entry forms, free contest entry form',
#  'membership application form, membership application form template, membership application form sample',
#  'Banking Application Forms',
#  'loan application form, loan apply form, loan application sample',
#  'animal rescue application',
#  'internship application form, internship application template',
#  'Medical Application Forms',
#  'rental application form, basic rental application form, free rental application form, rental application form template',
#  'pet adoption application form, pet adoption application form template',
#  'Guest Application Forms',
#  'credit application form, business credit application form',
#  'Tenant Application Forms, rental application form, tenant application form',
#  'volunteer application form, volunteer application form template, free volunteer application form template, generic volunteer application form, volunteer application form sample',
#  'vendor application form, vendors application form, vendor application form template',
#  'preorder form',
#  'catering order form, catering order forms',
#  'supply order form, supply order forms',
#  'florist order forms, flower shop order forms',
#  'Fundraising Order Forms, fundraising order form templates, online donation forms',
#  'Delivery Order Templates',
#  'Work Request Forms',
#  'Uniform Order Forms, uniform order',
#  'Exit Interview Templates, Exit Interview Template',
#  'Change Order Forms',
#  'Return to Work Forms, return to work form',
#  'contest registration form',
#  'camp registration forms, camp registration form',
#  'Membership Registration Forms',
#  'Conference Registration Form',
#  'volunteer registration form',
#  'sports registration form',
#  'course registration form, course registration form template',
#  'client registration form, customer registration form',
#  'school registration form',
#  'student registration form',
#  'workshop registration form, workshop registration form template',
#  'patient registration form, patient registration form template',
#  'hotel booking form, hotel booking forms',
#  'race registration forms, race registration form',
#  'Travel Booking Forms, travel booking',
#  'service booking',
#  'photography booking form',
#  'transportation request form',
#  'business registration form',
#  'animal shelter, animal rescue, animal shelter forms',
#  'photo release form, photo release form template',
#  'it request form',
#  'dance registration form, dance registration form template',
#  'information request form',
#  'quiz templates, quiz samples']

# %%
fig=make_subplots(rows=4, cols=1,
                      subplot_titles=("y-yhat", "Trend", "Seasonal_yearly","resid"))
fig.add_trace(
    go.Scatter(x=season.index,y=season.obs),row=1,col=1
    
)
fig.add_trace(
    go.Scatter(x=season.index,y=season.trend),row=2,col=1
)
fig.add_trace(
    go.Scatter(x=season.index,y=season.seasonal),row=3,col=1
    
)
fig.add_trace(
    go.Scatter(x=season.index,y=season.resid),row=4,col=1
    
)


fig.update_layout(height=1500, width=1500)
# Out:
# FigureWidgetResampler({
#     'data': [{'name': '<b style="color:sandybrown">[R]</b> trace 0 <i style="color:#fc9944">~1D</i>',
#               'type': 'scatter',
#               'uid': '2383de1b-d097-4bd4-9496-4d23c3593438',
#               'x': array([datetime.datetime(2020, 4, 29, 0, 0),
#                           datetime.datetime(2020, 4, 30, 0, 0),
#                           datetime.datetime(2020, 5, 1, 0, 0), ...,
#                           datetime.datetime(2023, 7, 16, 0, 0),
#                           datetime.datetime(2023, 7, 18, 0, 0),
#                           datetime.datetime(2023, 7, 19, 0, 0)], dtype=object),
#               'xaxis': 'x',
#               'y': array([  1.,   1.,   1., ...,  95., 105.,  26.]),
#               'yaxis': 'y'},
#              {'name': '<b style="color:sandybrown">[R]</b> trace 1 <i style="color:#fc9944">~1D</i>',
#               'type': 'scatter',
#               'uid': '2753771b-956e-4e47-b79f-56a828468a57',
#               'x': array([datetime.datetime(2020, 4, 29, 0, 0),
#                           datetime.datetime(2020, 4, 30, 0, 0),
#                           datetime.datetime(2020, 5, 1, 0, 0), ...,
#                           datetime.datetime(2023, 7, 16, 0, 0),
#                           datetime.datetime(2023, 7, 17, 0, 0),
#                           datetime.datetime(2023, 7, 19, 0, 0)], dtype=object),
#               'xaxis': 'x2',
#               'y': array([42.78522911, 42.79855113, 42.81187315, ..., 83.34426898, 83.44854897,
#                           83.65710896]),
#               'yaxis': 'y2'},
#              {'name': '<b style="color:sandybrown">[R]</b> trace 2 <i style="color:#fc9944">~1D</i>',
#               'type': 'scatter',
#               'uid': 'c1aa6ade-c8c3-4f24-b759-c50225de48f8',
#               'x': array([datetime.datetime(2020, 4, 29, 0, 0),
#                           datetime.datetime(2020, 4, 30, 0, 0),
#                           datetime.datetime(2020, 5, 1, 0, 0), ...,
#                           datetime.datetime(2023, 7, 16, 0, 0),
#                           datetime.datetime(2023, 7, 18, 0, 0),
#                           datetime.datetime(2023, 7, 19, 0, 0)], dtype=object),
#               'xaxis': 'x3',
#               'y': array([  8.03752162,  -1.2727008 ,  11.41022746, ...,  -3.18136949,
#                            -1.08537598, -18.65107786]),
#               'yaxis': 'y3'},
#              {'name': '<b style="color:sandybrown">[R]</b> trace 3 <i style="color:#fc9944">~1D</i>',
#               'type': 'scatter',
#               'uid': '3c553e47-7cce-4a83-9344-35a8a5a4fbd0',
#               'x': array([datetime.datetime(2020, 4, 29, 0, 0),
#                           datetime.datetime(2020, 4, 30, 0, 0),
#                           datetime.datetime(2020, 5, 1, 0, 0), ...,
#                           datetime.datetime(2023, 7, 16, 0, 0),
#                           datetime.datetime(2023, 7, 18, 0, 0),
#                           datetime.datetime(2023, 7, 19, 0, 0)], dtype=object),
#               'xaxis': 'x4',
#               'y': array([-49.82275073, -40.52585033, -53.22210061, ...,  14.83710052,
#                            22.53254701, -39.00603111]),
#               'yaxis': 'y4'}],
#     'layout': {'annotations': [{'font': {'size': 16},
#                                 'showarrow': False,
#                                 'text': 'y-yhat',
#                                 'x': 0.5,
#                                 'xanchor': 'center',
#                                 'xref': 'paper',
#                                 'y': 1.0,
#                                 'yanchor': 'bottom',
#                                 'yref': 'paper'},
#                                {'font': {'size': 16},
#                                 'showarrow': False,
#                                 'text': 'Trend',
#                                 'x': 0.5,
#                                 'xanchor': 'center',
#                                 'xref': 'paper',
#                                 'y': 0.71875,
#                                 'yanchor': 'bottom',
#                                 'yref': 'paper'},
#                                {'font': {'size': 16},
#                                 'showarrow': False,
#                                 'text': 'Seasonal_yearly',
#                                 'x': 0.5,
#                                 'xanchor': 'center',
#                                 'xref': 'paper',
#                                 'y': 0.4375,
#                                 'yanchor': 'bottom',
#                                 'yref': 'paper'},
#                                {'font': {'size': 16},
#                                 'showarrow': False,
#                                 'text': 'resid',
#                                 'x': 0.5,
#                                 'xanchor': 'center',
#                                 'xref': 'paper',
#                                 'y': 0.15625,
#                                 'yanchor': 'bottom',
#                                 'yref': 'paper'}],
#                'height': 1500,
#                'template': '...',
#                'width': 1500,
#                'xaxis': {'anchor': 'y', 'domain': [0.0, 1.0]},
#                'xaxis2': {'anchor': 'y2', 'domain': [0.0, 1.0]},
#                'xaxis3': {'anchor': 'y3', 'domain': [0.0, 1.0]},
#                'xaxis4': {'anchor': 'y4', 'domain': [0.0, 1.0]},
#                'yaxis': {'anchor': 'x', 'domain': [0.84375, 1.0]},
#                'yaxis2': {'anchor': 'x2', 'domain': [0.5625, 0.71875]},
#                'yaxis3': {'anchor': 'x3', 'domain': [0.28125, 0.4375]},
#                'yaxis4': {'anchor': 'x4', 'domain': [0.0, 0.15625]}}
# })

# %%
import modeltrainer

model=modeltrainer.model_trainer(df,"GamingForms")

# %%
df2=df.copy()
df2["y"]=df2["y"].rolling(window=7).mean()
df2=df2.dropna()

# %%
model2=torch.load("/home/batuhan-saylam/Desktop/JotformProject/projects/Formmodels/GamingForms52.pt")
model2.restore_trainer()
# Out:
# INFO - (NP.utils.configure_trainer) - Using accelerator gpu with -1 device(s).

# %%
forecast=model2.predict(df2)
# Out:
# INFO - (NP.df_utils._infer_frequency) - Major frequency D corresponds to 99.742% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - D
# INFO - (NP.df_utils._infer_frequency) - Major frequency D corresponds to 99.742% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - D
# Predicting: 0it [00:00, ?it/s]
# INFO - (NP.df_utils.return_df_in_original_format) - Returning df with no ID column

# %%
fig=make_subplots(rows=4, cols=1,
                      subplot_titles=("y-yhat", "Trend", "Seasonal_yearly"))
fig.add_trace(
    go.Scatter(x=forecast["ds"],y=forecast["y"],mode='markers'),row=1,col=1
)
fig.add_trace(
    go.Scatter(x=forecast["ds"],y=forecast["yhat1"]),row=1,col=1
    
)
fig.add_trace(
    go.Scatter(x=forecast["ds"],y=forecast["trend"]),row=2,col=1
)
fig.add_trace(
    go.Scatter(x=forecast["ds"],y=forecast["season_yearly"]),row=3,col=1
    
)



fig.update_layout(height=1500, width=1500)
# Out:
# FigureWidgetResampler({
#     'data': [{'mode': 'markers',
#               'name': '<b style="color:sandybrown">[R]</b> trace 0 <i style="color:#fc9944">~1D</i>',
#               'type': 'scatter',
#               'uid': '37f546aa-9293-4460-baa5-c1a17d9783b1',
#               'x': array([datetime.datetime(2020, 5, 8, 0, 0),
#                           datetime.datetime(2020, 5, 11, 0, 0),
#                           datetime.datetime(2020, 5, 13, 0, 0), ...,
#                           datetime.datetime(2023, 7, 16, 0, 0),
#                           datetime.datetime(2023, 7, 18, 0, 0),
#                           datetime.datetime(2023, 7, 19, 0, 0)], dtype=object),
#               'xaxis': 'x',
#               'y': array([ 1.28571429,  1.28571429,  1.28571429, ..., 86.85714286, 88.42857143,
#                           79.14285714]),
#               'yaxis': 'y'},
#              {'name': '<b style="color:sandybrown">[R]</b> trace 1 <i style="color:#fc9944">~1D</i>',
#               'type': 'scatter',
#               'uid': '418a66eb-cee1-4cb2-97c5-822c8fcde23b',
#               'x': array([datetime.datetime(2020, 5, 8, 0, 0),
#                           datetime.datetime(2020, 5, 11, 0, 0),
#                           datetime.datetime(2020, 5, 13, 0, 0), ...,
#                           datetime.datetime(2023, 7, 16, 0, 0),
#                           datetime.datetime(2023, 7, 18, 0, 0),
#                           datetime.datetime(2023, 7, 19, 0, 0)], dtype=object),
#               'xaxis': 'x',
#               'y': array([ 9.58571911,  9.93066216, 10.10334206, ..., 46.15683746, 45.25097275,
#                           44.8758049 ]),
#               'yaxis': 'y'},
#              {'name': '<b style="color:sandybrown">[R]</b> trace 2 <i style="color:#fc9944">~1D</i>',
#               'type': 'scatter',
#               'uid': '5c83d38d-84ca-4c3a-8748-f5fcb4bd053c',
#               'x': array([datetime.datetime(2020, 5, 8, 0, 0),
#                           datetime.datetime(2020, 5, 11, 0, 0),
#                           datetime.datetime(2020, 5, 13, 0, 0), ...,
#                           datetime.datetime(2023, 7, 16, 0, 0),
#                           datetime.datetime(2023, 7, 17, 0, 0),
#                           datetime.datetime(2023, 7, 19, 0, 0)], dtype=object),
#               'xaxis': 'x2',
#               'y': array([ 7.02163792,  7.33476877,  7.54352283, ..., 80.86204529, 81.0032196 ,
#                           81.28556061]),
#               'yaxis': 'y2'},
#              {'name': '<b style="color:sandybrown">[R]</b> trace 3 <i style="color:#fc9944">~1D</i>',
#               'type': 'scatter',
#               'uid': '4aa99409-d648-445f-9b32-5ee42113d5ad',
#               'x': array([datetime.datetime(2020, 5, 8, 0, 0),
#                           datetime.datetime(2020, 5, 11, 0, 0),
#                           datetime.datetime(2020, 5, 13, 0, 0), ...,
#                           datetime.datetime(2023, 7, 16, 0, 0),
#                           datetime.datetime(2023, 7, 18, 0, 0),
#                           datetime.datetime(2023, 7, 19, 0, 0)], dtype=object),
#               'xaxis': 'x3',
#               'y': array([  2.56408119,   2.59589338,   2.55982018, ..., -34.70520782,
#                           -35.89341736, -36.40975571]),
#               'yaxis': 'y3'}],
#     'layout': {'annotations': [{'font': {'size': 16},
#                                 'showarrow': False,
#                                 'text': 'y-yhat',
#                                 'x': 0.5,
#                                 'xanchor': 'center',
#                                 'xref': 'paper',
#                                 'y': 1.0,
#                                 'yanchor': 'bottom',
#                                 'yref': 'paper'},
#                                {'font': {'size': 16},
#                                 'showarrow': False,
#                                 'text': 'Trend',
#                                 'x': 0.5,
#                                 'xanchor': 'center',
#                                 'xref': 'paper',
#                                 'y': 0.71875,
#                                 'yanchor': 'bottom',
#                                 'yref': 'paper'},
#                                {'font': {'size': 16},
#                                 'showarrow': False,
#                                 'text': 'Seasonal_yearly',
#                                 'x': 0.5,
#                                 'xanchor': 'center',
#                                 'xref': 'paper',
#                                 'y': 0.4375,
#                                 'yanchor': 'bottom',
#                                 'yref': 'paper'}],
#                'height': 1500,
#                'template': '...',
#                'width': 1500,
#                'xaxis': {'anchor': 'y', 'domain': [0.0, 1.0]},
#                'xaxis2': {'anchor': 'y2', 'domain': [0.0, 1.0]},
#                'xaxis3': {'anchor': 'y3', 'domain': [0.0, 1.0]},
#                'xaxis4': {'anchor': 'y4', 'domain': [0.0, 1.0]},
#                'yaxis': {'anchor': 'x', 'domain': [0.84375, 1.0]},
#                'yaxis2': {'anchor': 'x2', 'domain': [0.5625, 0.71875]},
#                'yaxis3': {'anchor': 'x3', 'domain': [0.28125, 0.4375]},
#                'yaxis4': {'anchor': 'x4', 'domain': [0.0, 0.15625]}}
# })
