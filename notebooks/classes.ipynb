# %%
import pandas as pd 
import numpy as np


import pandasql as psql
#machine learning and statistical methods

#selected preprocessing and evaluation methods

from plotly.subplots import make_subplots
from statsmodels.tsa.seasonal import DecomposeResult
import plotly.graph_objects as go
from statsmodels.tsa.seasonal import seasonal_decompose
from sklearn.model_selection import TimeSeriesSplit

# %%
formtemplatesclones=pd.read_csv("/home/batuhan-saylam/Desktop/JotformProject/formTemplatesClones.csv",parse_dates=["date"])
formtemplatescategories=pd.read_csv("/home/batuhan-saylam/Desktop/JotformProject/formTemplatesCategories.csv")
formtemplates=pd.read_excel("/home/batuhan-saylam/Desktop/JotformProject/formTemplates_1_.xlsx")

# %%
formtemplatescategoriesy=formtemplatescategories.copy()
formtemplatesclones=formtemplatesclones.rename({"templateID":"_id"},axis=1)
formandclone=pd.merge(formtemplates,formtemplatesclones,how="inner",on="_id")
formtemplates1=formtemplates.copy()
formtemplates1=formtemplates1.rename({"_id":"id"},axis=1)
formtemplates1=formtemplates1.rename({"_featuredCategory":"_id"},axis=1)
df1_melt = formtemplates1.assign(_categories=formtemplates1._categories.str.split(","))
formtemplates1=df1_melt._categories.apply(pd.Series) \
    .merge(formtemplates1, right_index=True, left_index=True) \
    .drop(["_categories"], axis=1) \
    .melt(id_vars=['id',"_title","_slug","_description","_id","_language"], value_name="_categories") \
    .drop("variable", axis=1) 
formtemplates2=pd.merge(formtemplatescategoriesy,formtemplates1,how="inner",on="_id")
formtemplates2=formtemplates2.rename({"_id":"_featuredCategory"},axis=1)
formtemplates1=formtemplates1.rename({"_id":"_featuredCategory"},axis=1)

# %%
formtemplates1
# Out:
#                       id                                             _title  \
# 0            10175020727                        Simple Employee Application
# 1            10243036686                                        Quick Quote
# 2            10403313912                            Facilities request form
# 3            10471410826                                  Ghislaine_Contact
# 4            10613649813                                Ghislaine_Producten
# ...                  ...                                                ...
# 11449155  93420783566161                      Inside Sales Call Report Form
# 11449156  93420809987167                            Daily Leads Report Form
# 11449157  93420845091153              Inside Sales Daily Emails Report Form
# 11449158  93420896655468  Ø§Ø³ØªÙ…Ø§Ø±Ø© Ø§Ù„ØªØ³Ø¬ÙŠÙ„ ÙÙŠ Ø¯ÙˆØ±Ø© Øª...
# 11449159  93421610431142                     Inside Sales Email Report Form
#
#                                           _slug  \
# 0                             job-application-3
# 1                         quick-quote-private-2
# 2              calendar-facilities-request-form
# 3                              ghislainecontact
# 4                            ghislaineproducten
# ...                                         ...
# 11449155          inside-sales-call-report-form
# 11449156                daily-leads-report-form
# 11449157  inside-sales-daily-emails-report-form
# 11449158                 ltsgyl-fy-dwrh-tdrybyh
# 11449159         inside-sales-email-report-form
#
#                                                _description  \
# 0         Here's a nice little employment application th...
# 1         \nInvestment Property Loans\n\n\nNo tax or per...
# 2         This form allows you to manage in a very effic...
# 3                                                  contact
# 4                                                producten
# ...                                                     ...
# 11449155  Here is a daily call report form that is craft...
# 11449156  Here is a daily leads report form for inside s...
# 11449157  Here is a daily email report form that is craf...
# 11449158  Ù†Ù…ÙˆØ°Ø¬ ØªØ³Ø¬ÙŠÙ„ ÙÙŠ Ø¯ÙˆØ±Ø© ØªØ¯Ø±ÙŠØ¨...
# 11449159  <p class=\"description-area\" style=\"padding:...
#
#                  _featuredCategory _language               _categories
# 0                       9134504740        en  4f854c5a365599ea2c000009
# 1                              NaN        en  4f854c5a365599ea2c00001c
# 2                       9127600941        en  4f854c5a365599ea2c000017
# 3                              NaN        nl  4f854c5a365599ea2c000009
# 4                              NaN        nl  4f854c5a365599ea2c000009
# ...                            ...       ...                       ...
# 11449155  4f855d5aceae3f4968000000        en                       NaN
# 11449156  4f855d5aceae3f4968000000        en                       NaN
# 11449157  4f855d5aceae3f4968000000        en                       NaN
# 11449158                9248123036        ar                       NaN
# 11449159  4f855d5aceae3f4968000000        en                       NaN
#
# [11449160 rows x 7 columns]

# %%
formtemplates1=formtemplates1.rename({"_categories":"_id"},axis=1)
formtemplates3=pd.merge(formtemplatescategoriesy,formtemplates1,how="inner",on="_id")
formtemplates3=formtemplates3.rename({"_id":"_categories"},axis=1)
formtemplates1=formtemplates1.rename({"_id":"_categories"},axis=1)
formtemplates1=formtemplates1.rename({"id":"_id"},axis=1)
formtemplatesclones=formtemplatesclones.rename({"_id":"templateID"},axis=1)
formtemplates2=formtemplates2.drop_duplicates()
formtemplates3=formtemplates3.drop_duplicates()

# %%
formtemplates2
# Out:
#                _featuredCategory               name          slug  \
# 0       4f854c5a365599ea2c000001      Contact Forms  contact-form
# 1       4f854c5a365599ea2c000001      Contact Forms  contact-form
# 2       4f854c5a365599ea2c000001      Contact Forms  contact-form
# 3       4f854c5a365599ea2c000001      Contact Forms  contact-form
# 4       4f854c5a365599ea2c000001      Contact Forms  contact-form
# ...                          ...                ...           ...
# 798460  5c3f238e8a021f5c833d4331  Photography Forms   photography
# 798471  5c3f238e8a021f5c833d4331  Photography Forms   photography
# 798495  5c3f238e8a021f5c833d4331  Photography Forms   photography
# 798519  5c3f238e8a021f5c833d4331  Photography Forms   photography
# 798543  5c3f238e8a021f5c833d4331  Photography Forms   photography
#
#                                               description      pageTitle  \
# 0       Contact forms are an essential part of any bus...  Contact Forms
# 1       Contact forms are an essential part of any bus...  Contact Forms
# 2       Contact forms are an essential part of any bus...  Contact Forms
# 3       Contact forms are an essential part of any bus...  Contact Forms
# 4       Contact forms are an essential part of any bus...  Contact Forms
# ...                                                   ...            ...
# 798460  Looking for online photography forms? Jotform ...            NaN
# 798471  Looking for online photography forms? Jotform ...            NaN
# 798495  Looking for online photography forms? Jotform ...            NaN
# 798519  Looking for online photography forms? Jotform ...            NaN
# 798543  Looking for online photography forms? Jotform ...            NaN
#
#              metaKeywords               id  \
# 0           Contact Forms  200122438355042
# 1           Contact Forms  200205206936143
# 2           Contact Forms  200351465180042
# 3           Contact Forms  200544196772357
# 4           Contact Forms  200548992928873
# ...                   ...              ...
# 798460  Photography Forms   92622840008351
# 798471  Photography Forms   71571279433864
# 798495  Photography Forms   71571279433864
# 798519  Photography Forms   71571279433864
# 798543  Photography Forms   71571279433864
#
#                                                    _title  \
# 0                               Get In Touch Contact Form
# 1                              Bridal Makeup Contact Form
# 2                                      Popup Contact Form
# 3                        Contact Form Template in Italian
# 4                                   Enquiry Form Template
# ...                                                   ...
# 798460       Fecha TÃ©cnica de ColecciÃ³n de FotografÃ­as
# 798471  InformaciÃ³n de contacto y servicio de fotogra...
# 798495  InformaciÃ³n de contacto y servicio de fotogra...
# 798519  InformaciÃ³n de contacto y servicio de fotogra...
# 798543  InformaciÃ³n de contacto y servicio de fotogra...
#
#                                                    _slug  \
# 0                              get-in-touch-contact-form
# 1                             bridal-makeup-contact-form
# 2                                     popup-contact-form
# 3                       contact-form-template-in-italian
# 4                                  enquiry-form-template
# ...                                                  ...
# 798460         fecha-tecnica-de-coleccion-de-fotografias
# 798471  informacion-de-contacto-y-servicio-de-fotografia
# 798495  informacion-de-contacto-y-servicio-de-fotografia
# 798519  informacion-de-contacto-y-servicio-de-fotografia
# 798543  informacion-de-contacto-y-servicio-de-fotografia
#
#                                              _description _language  \
# 0       <p>A Get In Touch Contact Form is used to coll...        en
# 1       A bridal makeup contact form gathering bride's...        en
# 2       A Popup Contact Form is used to collect contac...        en
# 3       Contact form provides you with the submitters'...        it
# 4       Enquiry form template asks your submitters on ...        en
# ...                                                   ...       ...
# 798460  <p>Si organiza exposiciones de arte o fotograf...        es
# 798471  <p>Dirigida a fotÃ³grafos profesionales especi...        es
# 798495  <p>Dirigida a fotÃ³grafos profesionales especi...        es
# 798519  <p>Dirigida a fotÃ³grafos profesionales especi...        es
# 798543  <p>Dirigida a fotÃ³grafos profesionales especi...        es
#
#                      _categories
# 0
# 1       4f854c5a365599ea2c000017
# 2       4f854c5a365599ea2c000009
# 3
# 4
# ...                          ...
# 798460                       NaN
# 798471                9135076442
# 798495  4f854c5a365599ea2c000015
# 798519
# 798543                       NaN
#
# [19718 rows x 12 columns]

# %%
formtemplates3
# Out:
#       _categories            name            slug  \
# 0      1013514931  Pharmacy Forms  pharmacy-forms
# 1      1013514931  Pharmacy Forms  pharmacy-forms
# 2      1013514931  Pharmacy Forms  pharmacy-forms
# 3      1013514931  Pharmacy Forms  pharmacy-forms
# 4      1013514931  Pharmacy Forms  pharmacy-forms
# ...           ...             ...             ...
# 86132  9283064443         Quizzes   quiz-template
# 86133  9283064443         Quizzes   quiz-template
# 86134  9283064443         Quizzes   quiz-template
# 86135  9283064443         Quizzes   quiz-template
# 86136  9283064443         Quizzes   quiz-template
#
#                                              description pageTitle  \
# 0      Free online forms for your pharmacy. Whether y...       NaN
# 1      Free online forms for your pharmacy. Whether y...       NaN
# 2      Free online forms for your pharmacy. Whether y...       NaN
# 3      Free online forms for your pharmacy. Whether y...       NaN
# 4      Free online forms for your pharmacy. Whether y...       NaN
# ...                                                  ...       ...
# 86132  Create interactive quizzes for your school or ...       NaN
# 86133  Create interactive quizzes for your school or ...       NaN
# 86134  Create interactive quizzes for your school or ...       NaN
# 86135  Create interactive quizzes for your school or ...       NaN
# 86136  Create interactive quizzes for your school or ...       NaN
#
#                        metaKeywords               id  \
# 0                    Pharmacy Forms  203651425373149
# 1                    Pharmacy Forms  210063102726037
# 2                    Pharmacy Forms  210075599735969
# 3                    Pharmacy Forms  210114594077048
# 4                    Pharmacy Forms  210255742988060
# ...                             ...              ...
# 86132  quiz templates, quiz samples   90095431342148
# 86133  quiz templates, quiz samples   93245428785165
# 86134  quiz templates, quiz samples  200860054262446
# 86135  quiz templates, quiz samples  201346124481043
# 86136  quiz templates, quiz samples  201530442594147
#
#                                                   _title  \
# 0               COVID-19 Vaccination E-registration Form
# 1      CDC COVID-19 Vaccination Program Provider Agre...
# 2                              Prescription Request Form
# 3              CDC COVID-19 Vaccine Immunization Records
# 4                   COVID-19 Vaccine Administration Form
# ...                                                  ...
# 86132             Alternative Education Site Application
# 86133                                 Office365 Contacts
# 86134                                   Broti Order Form
# 86135  FICHA DE INSCRIPCIÃ“N FÃšTBOL TEMPORADA 20/21 ...
# 86136                           Custom Simple Order Form
#
#                                                    _slug  \
# 0      covid-19-vaccination-e-registration-jan-15-202...
# 1      cdc-covid-19-vaccination-program-provider-agre...
# 2                              prescription-request-form
# 3              cdc-covid-19-vaccine-immunization-records
# 4                   covid-19-vaccine-administration-form
# ...                                                  ...
# 86132                                        private-211
# 86133                                 office365-contacts
# 86134                         broti-order-form-private-1
# 86135  ficha-de-inscripcion-futbol-temporada-20-21-cp...
# 86136                 custom-simple-order-form-private-4
#
#                                             _description  \
# 0      <p>The COVID-19 Vaccination E-registration For...
# 1      The CDC (Centers of Disease Control and Preven...
# 2      <p>Prescription Request Form is a document or ...
# 3                                               CDC form
# 4      COVID-19 Vaccine Administration Form allows pa...
# ...                                                  ...
# 86132                                            AE Form
# 86133                                              share
# 86134                                               TEST
# 86135                                   INCRIPCIÃ“N CLUB
# 86136                                              order
#
#               _featuredCategory _language
# 0                           NaN        en
# 1                    1082515029        en
# 2      4f854c5a365599ea2c00000e        en
# 3                    1082515029        en
# 4                    1082515029        en
# ...                         ...       ...
# 86132                       NaN        aa
# 86133                       NaN        aa
# 86134                       NaN        aa
# 86135                       NaN        aa
# 86136                       NaN        en
#
# [86134 rows x 12 columns]

# %%
formcat=pd.concat([formtemplates2,formtemplates3]).drop_duplicates()
formcat=formcat.rename({"id":"_id"},axis=1)
formcat=formcat.loc[:,[
    'name',
    'description',
    'metaKeywords',
    '_categories',
    '_id']]
formandclone=formandclone.loc[:,[
'_id',
    '_title',
    '_slug',
    '_description',
    '_language',
    '_featuredCategory',
    'formID',
    'form_type',
    'source',
    'date']]

# %%
formcat
# Out:
#                 name                                        description  \
# 0      Contact Forms  Contact forms are an essential part of any bus...
# 1      Contact Forms  Contact forms are an essential part of any bus...
# 2      Contact Forms  Contact forms are an essential part of any bus...
# 3      Contact Forms  Contact forms are an essential part of any bus...
# 4      Contact Forms  Contact forms are an essential part of any bus...
# ...              ...                                                ...
# 86132        Quizzes  Create interactive quizzes for your school or ...
# 86133        Quizzes  Create interactive quizzes for your school or ...
# 86134        Quizzes  Create interactive quizzes for your school or ...
# 86135        Quizzes  Create interactive quizzes for your school or ...
# 86136        Quizzes  Create interactive quizzes for your school or ...
#
#                        metaKeywords               _categories              _id
# 0                     Contact Forms                            200122438355042
# 1                     Contact Forms  4f854c5a365599ea2c000017  200205206936143
# 2                     Contact Forms  4f854c5a365599ea2c000009  200351465180042
# 3                     Contact Forms                            200544196772357
# 4                     Contact Forms                            200548992928873
# ...                             ...                       ...              ...
# 86132  quiz templates, quiz samples                9283064443   90095431342148
# 86133  quiz templates, quiz samples                9283064443   93245428785165
# 86134  quiz templates, quiz samples                9283064443  200860054262446
# 86135  quiz templates, quiz samples                9283064443  201346124481043
# 86136  quiz templates, quiz samples                9283064443  201530442594147
#
# [100750 rows x 5 columns]

# %%
formandclone
# Out:
#                     _id                                             _title  \
# 0           10175020727                        Simple Employee Application
# 1           10175020727                        Simple Employee Application
# 2           10175020727                        Simple Employee Application
# 3           10175020727                        Simple Employee Application
# 4           10175020727                        Simple Employee Application
# ...                 ...                                                ...
# 8961565  93420896655468  Ø§Ø³ØªÙ…Ø§Ø±Ø© Ø§Ù„ØªØ³Ø¬ÙŠÙ„ ÙÙŠ Ø¯ÙˆØ±Ø© Øª...
# 8961566  93421610431142                     Inside Sales Email Report Form
# 8961567  93421610431142                     Inside Sales Email Report Form
# 8961568  93421610431142                     Inside Sales Email Report Form
# 8961569  93421610431142                     Inside Sales Email Report Form
#
#                                   _slug  \
# 0                     job-application-3
# 1                     job-application-3
# 2                     job-application-3
# 3                     job-application-3
# 4                     job-application-3
# ...                                 ...
# 8961565          ltsgyl-fy-dwrh-tdrybyh
# 8961566  inside-sales-email-report-form
# 8961567  inside-sales-email-report-form
# 8961568  inside-sales-email-report-form
# 8961569  inside-sales-email-report-form
#
#                                               _description _language  \
# 0        Here's a nice little employment application th...        en
# 1        Here's a nice little employment application th...        en
# 2        Here's a nice little employment application th...        en
# 3        Here's a nice little employment application th...        en
# 4        Here's a nice little employment application th...        en
# ...                                                    ...       ...
# 8961565  Ù†Ù…ÙˆØ°Ø¬ ØªØ³Ø¬ÙŠÙ„ ÙÙŠ Ø¯ÙˆØ±Ø© ØªØ¯Ø±ÙŠØ¨...        ar
# 8961566  <p class=\"description-area\" style=\"padding:...        en
# 8961567  <p class=\"description-area\" style=\"padding:...        en
# 8961568  <p class=\"description-area\" style=\"padding:...        en
# 8961569  <p class=\"description-area\" style=\"padding:...        en
#
#                 _featuredCategory           formID form_type     source  \
# 0                      9134504740  200010384803440       OLD  TEMPLATES
# 1                      9134504740  200022509812442       OLD  TEMPLATES
# 2                      9134504740  200038449888162       OLD  TEMPLATES
# 3                      9134504740  200053141418440       OLD  TEMPLATES
# 4                      9134504740  200075837085456       OLD  TEMPLATES
# ...                           ...              ...       ...        ...
# 8961565                9248123036  231988531281563       OLD  TEMPLATES
# 8961566  4f855d5aceae3f4968000000  211001012553533       OLD  TEMPLATES
# 8961567  4f855d5aceae3f4968000000  211762983269467       OLD  TEMPLATES
# 8961568  4f855d5aceae3f4968000000  211763462788466       OLD  TEMPLATES
# 8961569  4f855d5aceae3f4968000000  231420744755455       OLD  TEMPLATES
#
#                        date
# 0       2020-01-02 00:28:52
# 1       2020-01-03 04:37:50
# 2       2020-01-04 21:15:24
# 3       2020-01-06 08:43:05
# 4       2020-01-08 13:29:25
# ...                     ...
# 8961565 2023-07-18 21:55:55
# 8961566 2021-04-11 01:31:59
# 8961567 2021-06-26 08:07:49
# 8961568 2021-06-26 08:07:49
# 8961569 2023-05-23 01:35:03
#
# [8961570 rows x 10 columns]

# %%
import pandas as pd 
import numpy as np


import pandasql as psql
#machine learning and statistical methods

#selected preprocessing and evaluation methods

from statsmodels.tsa.seasonal import seasonal_decompose

from plotly.subplots import make_subplots
import plotly.graph_objects as go


class decompose:
    def __init__(self):
        self.formtemplatesclones0=pd.read_csv("/home/batuhan-saylam/Desktop/JotformProject/formTemplatesClones.csv",parse_dates=["date"])
        self.formtemplatescategories0=pd.read_csv("/home/batuhan-saylam/Desktop/JotformProject/formTemplatesCategories.csv")
        self.formtemplates0=pd.read_excel("/home/batuhan-saylam/Desktop/JotformProject/formTemplates_1_.xlsx")
    def sd(self,yaxis):
        self.formtemplatesclones=self.formtemplatesclones0.copy()
        self.formtemplatescategories=self.formtemplatescategories0.copy()
        self.formtemplates=self.formtemplates0.copy()
        self.yaxis=yaxis                    
        self.formtemplatescategoriesy=self.formtemplatescategories[self.formtemplatescategories["metaKeywords"]==self.yaxis].copy()
        self.formtemplatesclones=self.formtemplatesclones.rename({"templateID":"_id"},axis=1)
        formandclone=pd.merge(self.formtemplates,self.formtemplatesclones,how="inner",on="_id")
        self.formtemplates=self.formtemplates.rename({"_id":"id"},axis=1)
        self.formtemplates=self.formtemplates.rename({"_featuredCategory":"_id"},axis=1)
        self.formtemplates2=pd.merge(self.formtemplatescategoriesy,self.formtemplates,how="inner",on="_id")
        self.formtemplates2=self.formtemplates2.rename({"_id":"_featuredCategory"},axis=1)
        self.formtemplates=self.formtemplates.rename({"_id":"_featuredCategory"},axis=1)
        df_melt = self.formtemplates.assign(_categories=self.formtemplates._categories.str.split(","))
        self.formtemplates=df_melt._categories.apply(pd.Series) \
            .merge(self.formtemplates, right_index=True, left_index=True) \
            .drop(["_categories"], axis=1) \
            .melt(id_vars=['id',"_title","_slug","_description","_featuredCategory","_language"], value_name="_categories") \
            .drop("variable", axis=1) 
        self.formtemplates=self.formtemplates.rename({"_categories":"_id"},axis=1)
        self.formtemplates3=pd.merge(self.formtemplatescategoriesy,self.formtemplates,how="inner",on="_id")
        self.formtemplates3=self.formtemplates3.rename({"_id":"_categories"},axis=1)
        self.formtemplates=self.formtemplates.rename({"_id":"_categories"},axis=1)
        self.formtemplates=self.formtemplates.rename({"id":"_id"},axis=1)
        self.formtemplatesclones=self.formtemplatesclones.rename({"_id":"templateID"},axis=1)
        formcat=pd.concat([self.formtemplates2,self.formtemplates3])
        formcat=formcat.rename({"id":"_id"},axis=1)
        formcat=formcat.loc[:,[
        'name',
        'description',
        'metaKeywords',
        '_categories',
        '_id']]
        formandclone=formandclone.loc[:,[
        '_id',
        '_title',
        '_slug',
        '_description',
        '_language',
        '_featuredCategory',
        'formID',
        'form_type',
        'source',
        'date']]
        formclonecategnonnany=pd.merge(formandclone,formcat,on="_id")
        formclonecategnonnany=formclonecategnonnany.drop_duplicates(keep='first')
        formclonecategnonnany.index=formclonecategnonnany.date
        formclonecategnonnany.index=formclonecategnonnany.index.to_period("D")
        formclonecategnonnany=formclonecategnonnany.rename({"date":"date2"},axis=1)
        formclonecategnonnany["day"]=formclonecategnonnany.index.dayofweek
        formclonecategnonnany["week"]=formclonecategnonnany.index.week
        formclonecategnonnany["dayofyear"]=formclonecategnonnany.index.dayofyear
        formclonecategnonnany["year"]=formclonecategnonnany.index.year
        formclonecategnonnany["quarter"]=formclonecategnonnany.index.quarter
        formclonecategnonnany["month"]=formclonecategnonnany.index.month
        formclonecategnonnany.index=formclonecategnonnany.index.to_timestamp()
        df=psql.sqldf("select count(_id),date,year,dayofyear,week,day,quarter,month from formclonecategnonnany  group by date")
        df.index=df.date.tolist()
        df.index=pd.to_datetime(df.index)
        df.index=df.index.to_period("D")
        df.index=df.index.to_timestamp()
        df.index=df.index.strftime('%d-%m-%Y')
        df["date"]=pd.to_datetime(df["date"])
        df=df.rename({"count(_id)":"y"},axis=1)
        df=df.rename({"date":"ds"},axis=1)
        df=df.loc[:,["y","ds"]]
        df=df.resample('7D',on="ds").sum()
        decomposeresult2=seasonal_decompose(df["y"],period=52,model="add",extrapolate_trend="freq",two_sided=True)
        self.season = pd.DataFrame({"obs":decomposeresult2.observed,"trend":decomposeresult2.trend,"seasonal":decomposeresult2.seasonal,"resid":decomposeresult2.resid})
        self.season.index=pd.to_datetime(self.season.index,format="%d-%m-%Y")
        self.season=self.season.fillna(0)
        self.season=self.season.sort_index()
        self.season.index=self.season.index.to_period("D")
        self.season.index=self.season.index.to_timestamp()
        self.season.index=self.season.index.strftime('%d-%m-%Y')
        self.season.index=pd.to_datetime(self.season.index,format='%d-%m-%Y')
        fig=make_subplots(rows=4, cols=1,
                        subplot_titles=(self.yaxis, "Trend", "Seasonal_yearly","resid"))
        fig.add_trace(
            go.Scatter(x=self.season.index,y=self.season.obs),row=1,col=1
            
        )
        fig.add_trace(
            go.Scatter(x=self.season.index,y=self.season.trend),row=2,col=1
        )
        fig.add_trace(
            go.Scatter(x=self.season.index,y=self.season.seasonal),row=3,col=1
            
        )
        fig.add_trace(
            go.Scatter(x=self.season.index,y=self.season.resid),row=4,col=1
            
        )


        fig.update_layout(height=1000, width=950)
        return fig
